# %%
import pandas as pd
import utils

# Plots all figures inside Jupyter Notebook
# %matplotlib inline

# Code to fetch the housing dataset on GH
# utils.fetch_housing_data()

# %%
# Reading data in Pandas in really simple.
housing = pd.read_csv("datasets/housing/housing_train.csv")

# %%
# You can also use list(housing) for simplicity
list(housing.columns)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
# Select a few rows to see what our data looks like
housing.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>...</th>
#       <th>PoolArea</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#       <th>SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>60</td>
#       <td>RL</td>
#       <td>65.0</td>
#       <td>8450</td>
#       <td>Pave</td>
#       <td>NaN</td>
#       <td>Reg</td>
#       <td>Lvl</td>
#       <td>AllPub</td>
#       <td>...</td>
#       <td>0</td>
#       <td>NaN</td>
# ...

# %%
# We can use column headers to index dataframes
housing[['YearBuilt','YearRemodAdd']].head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2003</td>
#       <td>2003</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1976</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2001</td>
#       <td>2002</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1915</td>
#       <td>1970</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2000</td>
#       <td>2000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# We can also use numbers to index dataframes
housing.ix[0:5, [2, 3, 5]]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>Street</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>RL</td>
#       <td>65.0</td>
#       <td>Pave</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>RL</td>
#       <td>80.0</td>
#       <td>Pave</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>RL</td>
#       <td>68.0</td>
#       <td>Pave</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>RL</td>
#       <td>60.0</td>
#       <td>Pave</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>RL</td>
#       <td>84.0</td>
#       <td>Pave</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>RL</td>
#       <td>85.0</td>
#       <td>Pave</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# housing['Street'] != 'Pave' returns an array of Booleans
not_paved = housing['Street'] != 'Pave'
print(not_paved.head())
housing[not_paved]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Street, dtype: bool
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>...</th>
#       <th>PoolArea</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#       <th>SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>52</th>
#       <td>53</td>
#       <td>90</td>
#       <td>RM</td>
#       <td>110.0</td>
#       <td>8472</td>
#       <td>Grvl</td>
#       <td>NaN</td>
#       <td>IR2</td>
# ...

# %%
# Ex. How many houses have a shed attached to them? ('MiscFeature')
len(housing[housing['MiscFeature'] == 'Shed'])
# Out:
# 49

# %%
# Which houses have 2nd floors larger than first floors?
first_second_diff = housing[['2ndFlrSF', '1stFlrSF']].copy()
first_second_diff['diff'] = first_second_diff['2ndFlrSF'] - first_second_diff['1stFlrSF']
first_second_diff.sort_values(by='diff', ascending=False).head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2ndFlrSF</th>
#       <th>1stFlrSF</th>
#       <th>diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>362</th>
#       <td>1427</td>
#       <td>495</td>
#       <td>932</td>
#     </tr>
#     <tr>
#       <th>1360</th>
#       <td>1611</td>
#       <td>990</td>
#       <td>621</td>
#     </tr>
#     <tr>
#       <th>800</th>
#       <td>1072</td>
#       <td>616</td>
#       <td>456</td>
#     </tr>
#     <tr>
#       <th>157</th>
#       <td>1194</td>
#       <td>774</td>
#       <td>420</td>
#     </tr>
#     <tr>
#       <th>1430</th>
#       <td>1104</td>
#       <td>734</td>
#       <td>370</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# We can also aggregate / group by:
housing.groupby('Fireplaces')

# %%
# How many houses were sold by month?
sold_by_volume = housing.groupby('MoSold').size()
sold_by_volume
# Out:
# MoSold
# 1      58
# 2      52
# 3     106
# 4     141
# 5     204
# 6     253
# 7     234
# 8     122
# 9      63
# 10     89
# 11     79
# 12     59
# dtype: int64

# %%
# Add some labels and a plot
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sold_by_volume.index = months
sold_by_volume.plot(kind='bar')

# %%
# Ex: How many houses were sold by month with basements larger than first floors?
housing[housing[""]]

# %%
expensive_houses = housing[housing['SalePrice'] > 310000]
expensive_sales = expensive_houses[['MoSold', 'SalePrice']].groupby('MoSold').aggregate(sum)
expensive_sales.index = months
expensive_sales.plot(kind='bar')

# %%
housing['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
median_price = housing['SalePrice'].median()
median_price
# Out:
# 163000.0

# %%
# Two options when cleaning data - fill or drop
# "Fill" can be done many ways. Here's a simple fill:
# cleanedPrices = housing['Price'].fillna(medianPrice)
cleanedPrices = housing.dropna(subset=['SalePrice'])[['YearBuilt', 'SalePrice']]
cleanedPrices['SalePrice'].plot(kind='hist')

# %%
# Plot sale price over year built

price_by_year_built = housing[['YearBuilt', 'SalePrice']]
price_by_year_built.plot(kind='scatter', x='YearBuilt', y='SalePrice')

# %%
# Plot sale price over general living area

price_by_living_area = housing[['GrLivArea', 'SalePrice']]
price_by_living_area.plot(kind='scatter', x='GrLivArea', y='SalePrice')

# %%
# Plot correlation matrix

import matplotlib.pyplot as plt
import seaborn as sns

corrmat = housing.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["YearBuilt", "GarageArea", "2ndFlrSF", "GrLivArea", "SalePrice"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11afeea20>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11badad30>]], dtype=object)

# %%
scatter_matrix(['SalePrice', 'FullBath'])

# %%
# Let's break up our data

from sklearn.model_selection import train_test_split # Can also use StratifiedShuffleSplit

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
print("Training set shape: " + str(train_set.shape))
housing_train = train_set.drop("SalePrice", axis=1)
print("Training data shape: " + str(housing_train.shape))
housing_labels = train_set["SalePrice"].copy()
print("Training labels: ")
print(str(housing_labels.head()))
train_set.describe()
# Out:
# Training set shape: (1168, 81)
# Training data shape: (1168, 80)
# Training labels:
# 254     145000
# 1066    178000
# 638      85000
# 799     175000
# 380     127000
# Name: SalePrice, dtype: int64
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#       <th>MasVnrArea</th>
#       <th>BsmtFinSF1</th>
#       <th>...</th>
#       <th>WoodDeckSF</th>
#       <th>OpenPorchSF</th>
#       <th>EnclosedPorch</th>
#       <th>3SsnPorch</th>
#       <th>ScreenPorch</th>
#       <th>PoolArea</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1168.000000</td>
# ...

# %%
# imputer.fit(housing)

training_numerical = housing_train._get_numeric_data()
numerical_attributes = list(training_numerical)
training_categorical = housing_train.select_dtypes(exclude=[np.number])
categorical_attributes = list(training_categorical)
# cleaned_data = imputer.fit(housing_num)
# cleaned_data
# X = imputer.transform(housing_num)
# X
print(training_numerical.shape)
print(training_categorical.shape)
numerical_attributes
# Out:
# (1168, 37)
# (1168, 43)
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# Encoding numerical attributres

from sklearn.preprocessing import Imputer
num_imputer = Imputer(strategy='median')
num_imputer.fit(training_numerical)
print("Imputer calculated medians: ", num_imputer.statistics_)
print("NaNs before filling medians: ", training_numerical.isnull().values.sum())
cleaned = num_imputer.transform(training_numerical)
print("NaNs after filling medians: ", np.count_nonzero(np.isnan(cleaned)))
# Out:
# Imputer calculated medians:  [  7.32500000e+02   5.00000000e+01   7.00000000e+01   9.60000000e+03
#    6.00000000e+00   5.00000000e+00   1.97200000e+03   1.99400000e+03
#    0.00000000e+00   3.84500000e+02   0.00000000e+00   4.80000000e+02
#    9.97500000e+02   1.09500000e+03   0.00000000e+00   0.00000000e+00
#    1.47300000e+03   0.00000000e+00   0.00000000e+00   2.00000000e+00
#    0.00000000e+00   3.00000000e+00   1.00000000e+00   6.00000000e+00
#    1.00000000e+00   1.98000000e+03   2.00000000e+00   4.82000000e+02
#    0.00000000e+00   2.70000000e+01   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   6.00000000e+00
#    2.00800000e+03]
# NaNs before filling medians:  287
# NaNs after filling medians:  0

# %%
# Encoding categorical attributres

from sklearn.preprocessing import MultiLabelBinarizer, LabelBinarizer, LabelEncoder
from sklearn.base import TransformerMixin
from collections import defaultdict

class CategoryImputer(TransformerMixin):
    fill = "NA"
    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):
        if X.dtype == np.dtype('O'):
            self.fill = X.value_counts().index[0]
        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# Adapted from http://stackoverflow.com/questions/24458645
class MultiColumnLabelEncoder:
    def __init__(self, columns=None):
        self.columns = columns  # array of column names to encode

    def fit(self, X, y=None):
        return self  # not relevant here

    def transform(self, X):
        d = defaultdict(LabelEncoder)
        # Encoding the variable
        fit = X.apply(lambda x: d[x.name].fit_transform(x))

        # Inverse the encoded
        fit.apply(lambda x: d[x.name].inverse_transform(x))

        # Using the dictionary to label future data
        return X.apply(lambda x: d[x.name].transform(x))

cat_imputer = CategoryImputer()
cleanedCats = cat_imputer.transform(training_categorical)

encoder = MultiColumnLabelEncoder()
encoder.fit(cleanedCats)
cats = encoder.transform(cleanedCats)
cats.head()
# Out:
# NA
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSZoning</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>...</th>
#       <th>GarageType</th>
#       <th>GarageFinish</th>
#       <th>GarageQual</th>
#       <th>GarageCond</th>
#       <th>PavedDrive</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>254</th>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#       <td>3</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>12</td>
#       <td>2</td>
#       <td>...</td>
#       <td>1</td>
# ...

# %%
# Custom Transformation

from sklearn.base import BaseEstimator
import numpy as np

garage_area_idx = training_numerical.columns.get_loc("GarageArea")
garage_cars_idx = training_numerical.columns.get_loc("GarageCars")

class CarSpaceAttributor(BaseEstimator, TransformerMixin):
    def __init__(self, myHyperParameter = True): # Add your hyperparameters here
        self.myHyperParameter = myHyperParameter
    def fit(self, X, y=None):
        return self  # nothing else to do
    def transform(self, X, y=None):
        space_per_car = X[:, garage_area_idx] / (X[:, garage_cars_idx] + 1)
        return np.c_[X, space_per_car]

attr_adder = CarSpaceAttributor()
housing_extra_attribs = attr_adder.transform(training_numerical.values)

print("Shape before: " + str(training_numerical.shape))
print("Shape after:  " + str(housing_extra_attribs.shape))

housing_extra_attribs[:5, -1]
# Out:
# Shape before: (1168, 37)
# Shape after:  (1168, 38)
# array([ 147.        ,  126.66666667,    0.        ,  120.        ,  154.        ])

# %%
# Ex. Write your own Transformer

# %%
# Transformation Pipelines

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler


class AttributeSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        return X[self.attribute_names].values


pipeline = Pipeline([
    ('selector', AttributeSelector(numerical_attributes)),
    ('imputer', Imputer(strategy="median")),
    ('attribs_adder', CarSpaceAttributor()),
    ('std_scaler', StandardScaler()),
])

cat_pipeline = Pipeline([
    ('selector', AttributeSelector(categorical_attributes)),
    ('encoder', encoder),
])

full_pipeline = FeatureUnion(transformer_list=[
    ("num_pipeline", pipeline),
    ("cat_pipeline", cat_pipeline),
])

housing_num_prepared = pipeline.fit_transform(housing_train)
print(housing_num_prepared.shape)
housing_num_prepared
# Out:
# (1168, 38)
# array([[-1.11928402, -0.8667643 , -0.01246836, ..., -0.13341669,
#          1.65006527, -0.27636638],
#        [ 0.79046412,  0.07410996, -0.50235683, ..., -0.5080097 ,
#          0.89367742, -0.64926208],
#        [-0.21615189, -0.63154574, -0.14607431, ..., -0.5080097 ,
#          0.13728958, -2.97221887],
#        ...,
#        [ 1.32669882, -0.8667643 , -0.45782152, ..., -0.88260272,
#         -1.37548612,  0.5244424 ],
#        [ 0.30597137, -0.16110861, -0.6804981 , ..., -0.13341669,
#         -0.61909827, -0.99159255],
#        [ 0.93157852,  1.48542135, -0.76956873, ..., -0.13341669,
#          0.89367742,  0.053738  ]])

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

lin_reg.fit(housing_num_prepared, housing_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Let's evaluate our model
some_data = housing_train.iloc[:5]
some_labels = housing_labels[:5]

some_data_prepared = pipeline.transform(some_data)
print("Predictions:", lin_reg.predict(some_data_prepared))
print("Labels:", list(some_labels))
# Out:
# Predictions: [ 136654.43954789  185195.83367052   96633.46511561  166478.31741116
#   128752.40822862]
# Labels: [145000, 178000, 85000, 175000, 127000]

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = lin_reg.predict(housing_num_prepared)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 33327.511975002606

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
from sklearn.model_selection import cross_val_score
lin_scores = cross_val_score(lin_reg, housing_num_prepared, housing_labels, scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [ 27118.72576087  45333.67388476  27617.94217957  45340.40628004
#   66782.4886775   38260.90446671  27215.01690596  23163.15517724
#   26217.08504357  26465.4238594 ]
# Mean: 35351.4822236
# Standard deviation: 13040.4685821

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(housing_num_prepared, housing_labels)
housing_predictions = forest_reg.predict(housing_num_prepared)
lin_scores = cross_val_score(forest_reg, housing_num_prepared, housing_labels, scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [ 22228.87723706  41778.53971289  23940.9541639   44853.11028784
#   46787.37453294  36967.43990216  30890.80429966  27475.95013357
#   27698.07078149  24995.03334801]
# Mean: 32761.61544
# Standard deviation: 8649.04712608
